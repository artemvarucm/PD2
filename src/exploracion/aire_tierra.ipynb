# %% [markdown]
# ### Análisis para el avión con ICAO = 343694

# %%
import pandas as pd
df = pd.read_csv('../../data/ex1/icao_343694.csv')
df['timestamp']
# Out:
# 0        1733292044372
# 1        1733292088412
# 2        1733292245387
# 3        1733292253918
# 4        1733292256967
#              ...
# 24449    1733387368823
# 24450    1733387381575
# 24451    1733387382053
# 24452    1733387386454
# 24453    1733387398141
# Name: timestamp, Length: 24454, dtype: int64

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2,1)

axs[0].plot(df.surface_velocity)
axs[1].plot(df.V)
